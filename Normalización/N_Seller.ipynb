# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\marco\Desktop\ProyectoGrupalH\data\olist_sellers_dataset.csv')

# %%
df.rename(columns = {'seller_zip_code_prefix': 'zip_code', 'seller_city': 'city', 'seller_state': 'state'}, inplace= True)

# %%
df.head(3)
# Out:
#                           seller_id  zip_code            city state
# 0  3442f8959a84dea7ee197c632cb2df15     13023        campinas    SP
# 1  d1b65fc7debc3361ea86b5f14c68d2e2     13844      mogi guacu    SP
# 2  ce3ad9de960102d0677a81f5d0bb7b2d     20031  rio de janeiro    RJ

# %%
df['city'] = df['city'].str.title()

# %%
dfgeo = pd.read_parquet(r'C:\Users\marco\Desktop\ProyectoGrupalH\dataparquet\geolocation_cleanP')
dfgeo.head(3)
# Out:
#    zip_code  geolatitud  geolongitud       city state state_name
# 0      1037  -23.545621   -46.639292  Sao Paulo    SP  São Paulo
# 1      1046  -23.546081   -46.644820  Sao Paulo    SP  São Paulo
# 2      1041  -23.544392   -46.639499  Sao Paulo    SP  São Paulo

# %%
df = df[['seller_id', 'zip_code']].merge(dfgeo[['zip_code','geolatitud', 'geolongitud', 'city', 'state', 'state_name']], on='zip_code')
df
# Out:
#                              seller_id  zip_code  geolatitud  geolongitud  \
# 0     3442f8959a84dea7ee197c632cb2df15     13023  -22.898536   -47.063125
# 1     e0eabded302882513ced4ea3eb0c7059     13023  -22.898536   -47.063125
# 2     d1b65fc7debc3361ea86b5f14c68d2e2     13844  -22.382941   -46.946641
# 3     ce3ad9de960102d0677a81f5d0bb7b2d     20031  -22.910641   -43.176510
# 4     1d2732ef8321502ee8488e8bed1ab8cd     20031  -22.910641   -43.176510
# ...                                ...       ...         ...          ...
# 3083  f1fdf2d13186575751aa25876536d85c      5314  -23.534949   -46.733916
# 3084  98dddbc4601dd4443ca174359b237166     87111  -23.456431   -51.866369
# 3085  74871d19219c7d518d0090283e03c137      4650  -23.659845   -46.677882
# 3086  e603cf3fec55f8697c9059638d6c8eb5     96080  -31.744231   -52.328761
# 3087  9e25199f6ef7e7c347120ff175652c3b     12051  -23.016003   -45.582021
#
#                 city state         state_name
# ...

# %%
df.to_parquet(r'C:\Users\marco\Desktop\ProyectoGrupalH\dataparquet\data_sellerP')
