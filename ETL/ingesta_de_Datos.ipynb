# %%
import mysql.connector as msql
from mysql.connector import Error

# %%
import pandas as pd

# %% [markdown]
# CREACIÓN DE BASE DE DATOS

# %%
try:
    conn = msql.connect(host='localhost', user='root',  
                        password='2685')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("CREATE DATABASE IF NOT EXISTS data_olist")
        print("Database is created")
except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# Database is created

# %% [markdown]
# CREACIÓN DE TABLAS

# %% [markdown]
# **VENDEDORES**

# %%
data_seller = pd.read_parquet(r'C:\Users\leand\Desktop\Data Science (Henry)\Proyectos\Proyecto_grupal\DS-Proyecto_Grupal_Olist\parquet_normalizados\data_sellerP')

# %%
data_seller.drop(columns= ['geolatitud', 'geolongitud', 'state'], inplace= True)

# %%
try:
    conn = msql.connect(host='localhost', database='data_olist', user='root', password='2685')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute('DROP TABLE IF EXISTS seller;')
        print('Creating table....')
        cursor.execute("CREATE TABLE seller(seller_id VARCHAR(255), zip_code INT(10), city VARCHAR(255), state_name VARCHAR(255), PRIMARY KEY(seller_id))")
        print("Table is created....")
        for i,row in data_seller.iterrows():
            #here %S means string values
            # Habria que chequear aca si funciona con los Ints o los Floats o Fechas,inclusive. Siempre creo que se usa el %s.
            sql = "INSERT INTO data_olist.seller VALUES (%s,%s,%s,%s)"
            cursor.execute(sql, tuple(row))
            print("Record inserted")
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('data_olist',)
# Creating table....
# Table is created....
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %% [markdown]
# **CLIENTES**

# %%
customer = pd.read_parquet(r'C:\Users\leand\Desktop\Data Science (Henry)\Proyectos\Proyecto_grupal\DS-Proyecto_Grupal_Olist\parquet_normalizados\data_customerP')

# %%
customer.drop(columns = ['geolatitud', 'geolongitud', 'state'], inplace=True)

# %%
customer.dtypes
# Out:
# customer_id           object
# customer_unique_id    object
# zip_code               int64
# city                  object
# state_name            object
# dtype: object

# %%
try:
    conn = msql.connect(host='localhost', database='data_olist', user='root', password='2685')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute("DROP TABLE IF EXISTS customer;")
        print('Creating table....')
        cursor.execute("CREATE TABLE customer (customer_id VARCHAR (255), customer_unique_id VARCHAR (255), zip_code INT(10), city VARCHAR (255), state_name VARCHAR(255), PRIMARY KEY (customer_id))")
        
        print("Table is created....")
        for i,row in customer.iterrows():
            #here %S means string values
            # Habria que chequear aca si funciona con los Ints o los Floats o Fechas,inclusive. Siempre creo que se usa el %s.
            sql = "INSERT INTO data_olist.customer VALUES (%s,%s,%s,%s,%s)"
            cursor.execute(sql, tuple(row))
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
        print(i, 'Registros insertados')
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('data_olist',)
# Creating table....
# Table is created....
# 99162 Registros insertados

# %% [markdown]
# **GEOLOCALIZACIÓN**

# %%
geolocation = pd.read_parquet(r'C:\Users\leand\Desktop\Data Science (Henry)\Proyectos\Proyecto_grupal\DS-Proyecto_Grupal_Olist\data_parquet\geolocation_cleanP')

# %%
'CONVERTIR ZIP CODE A STRING Y CARGARLO COMO VARCHAR'
geolocation['zip_code'] = geolocation['zip_code'].astype(str)         
geolocation.dtypes
# Out:
# zip_code        object
# geolatitud     float64
# geolongitud    float64
# city            object
# state_name      object
# dtype: object

# %%
try:
    conn = msql.connect(host='localhost', database='data_olist', user='root', password='2685')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute("DROP TABLE IF EXISTS geolocation;")
        print('Creating table....')
        cursor.execute("CREATE TABLE geolocation (zip_code VARCHAR(10), geolatitud DECIMAL (13,10), geolongitud DECIMAL (13,10), city VARCHAR (255),state_name VARCHAR(255), PRIMARY KEY (zip_code))")
        
             

        print("Table is created....")
        for i,row in geolocation.iterrows():
            #here %S means string values
            # Habria que chequear aca si funciona con los Ints o los Floats o Fechas,inclusive. Siempre creo que se usa el %s.
            sql = "INSERT INTO data_olist.geolocation VALUES (%s,%s,%s,%s,%s)"
            cursor.execute(sql, tuple(row))
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
        print(i, 'Registros insertados')
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('data_olist',)
# Creating table....
# Table is created....
# 19014 Registros insertados

# %% [markdown]
# **ORDER_REVIEWS**

# %%
review = pd.read_parquet(r'C:\Users\leand\Desktop\Data Science (Henry)\Proyectos\Proyecto_grupal\DS-Proyecto_Grupal_Olist\Normalización\data_order_review_NORMALIZADA')

# %%
# EN EL GITHUB FALTÓ ESTO
#review['review_creation_date'] = pd.to_datetime(review['review_creation_date'])

# %%
try:
    conn = msql.connect(host='localhost', database='data_olist', user='root', password='2685')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute("DROP TABLE IF EXISTS review;")
        print('Creating table....')
        cursor.execute("CREATE TABLE review (review_id INT(10), order_id VARCHAR (255), review_score INT(10), review_creation_date DATETIME, PRIMARY KEY (review_id))")
        
             

        print("Table is created....")
        for i,row in review.iterrows():
            #here %S means string values
            # Habria que chequear aca si funciona con los Ints o los Floats o Fechas,inclusive. Siempre creo que se usa el %s.
            sql = "INSERT INTO data_olist.review VALUES (%s,%s,%s, %s)"
            cursor.execute(sql, tuple(row))
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
        print(i, 'Registros insertados')
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('data_olist',)
# Creating table....
# Table is created....
# 99223 Registros insertados

# %% [markdown]
# **ORDER**

# %%
order = pd.read_parquet(r'C:\Users\leand\Desktop\Data Science (Henry)\Proyectos\Proyecto_grupal\DS-Proyecto_Grupal_Olist\Normalización\orders_normalizada_NORMALIZADA')

# %%
order.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object

# %%
try:
    conn = msql.connect(host='localhost', database='data_olist', user='root', password='2685')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute("DROP TABLE IF EXISTS table_order;")
        print('Creating table....')
        cursor.execute("CREATE TABLE table_order (order_id VARCHAR (255), customer_id VARCHAR (255), order_status VARCHAR (255), order_purchase_timestamp DATETIME(6),\
            order_approved_at DATETIME(6), order_delivered_carrier_date DATETIME(6), order_delivered_customer_date DATETIME(6),\
                 order_estimated_delivery_date DATETIME(6), PRIMARY KEY (order_id))")
        
        print("Table is created....")
        for i,row in order.iterrows():
            #here %S means string values
            # Habria que chequear aca si funciona con los Ints o los Floats o Fechas,inclusive. Siempre creo que se usa el %s.
            sql = "INSERT INTO data_olist.table_order VALUES (%s,%s,%s,%s,%s,%s,%s,%s)"
            cursor.execute(sql, tuple(row))
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
        print(i, 'Registros insertados')
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('data_olist',)
# Creating table....
# Table is created....
# 99440 Registros insertados

# %%
geo = pd.read_parquet(r'C:\Users\leand\Desktop\Data Science (Henry)\Proyectos\Proyecto_grupal\DS-Proyecto_Grupal_Olist\data_parquet\geolocation_cleanP')

# %%
geo.dtypes
# Out:
# zip_code         int64
# geolatitud     float64
# geolongitud    float64
# city            object
# state_name      object
# dtype: object
