# %%
import pandas as pd
import numpy as np

# %%
data_order_items = pd.read_parquet(r'C:\Users\leand\Desktop\Data Science (Henry)\Proyectos\Proyecto_grupal\DS-Proyecto_Grupal_Olist\data_parquet\data_order_itemsP')

# %%
data_order_items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
data_order = pd.read_parquet(r'C:\Users\leand\Desktop\Data Science (Henry)\Proyectos\Proyecto_grupal\DS-Proyecto_Grupal_Olist\Normalización\orders_normalizada')

# %%
data_order.head(2)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
#
#   order_estimated_delivery_date
# 0                    2017-10-18
# 1                    2018-08-13

# %%
d = data_order_items.merge(data_order, on = 'order_id')

# %%
d.head(3)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
#
#   shipping_limit_date  price  freight_value  percentagePF  \
# 0 2017-09-19 09:45:35   58.9          13.29     22.563667
# 1 2017-05-03 11:05:13  239.9          19.93      8.307628
# 2 2018-01-18 14:48:30  199.0          17.87      8.979899
#
#                         customer_id order_status order_purchase_timestamp  \
# 0  3ce436f183e68e07877b285a838db11a    delivered      2017-09-13 08:59:02
# 1  f6dd3ec061db4e3987629fe6b26e5cce    delivered      2017-04-26 10:53:06
# ...

# %%
d[d.shipping_limit_date < d.order_delivered_carrier_date].max()
# Out:
# order_id                         fffbee3b5462987e66fb49b1c5411df2
# order_item_id                                                  20
# product_id                       fff515ea94dbf35d54d256b3e39f0fea
# seller_id                        ffff564a4f9085cd26170f4732393726
# shipping_limit_date                           2018-08-29 13:44:29
# price                                                      6729.0
# freight_value                                               338.3
# percentagePF                                           529.142857
# customer_id                      ffffa3172527f765de70084a7e53aae8
# order_status                                              shipped
# order_purchase_timestamp                      2018-08-26 04:51:22
# order_approved_at                             2018-08-26 05:44:05
# order_delivered_carrier_date                  2018-09-11 19:48:28
# order_delivered_customer_date                 2018-09-19 16:44:44
# ...

# %% [markdown]
# **TENEMOS UN 10% DE LAS ÓRDENES QUE FUERON DESPECHADAS DESPUÈS DEL TIEMPO LÍMITE QUE TENÍA EL VENDEDOR. ESTUVIERON FLOJITOS AHÍ**

# %%
data_order_items.rename(columns= {'order_item_id' : 'quantity'}, inplace= True)

# %%
data_order_items = data_order_items.reindex(columns = ['order_id', 'product_id', 'seller_id', 'shipping_limit_date', 'quantity', 'price', 'freight_value', 'percentagePF'])

# %%
data_order_items.to_parquet('data_order_items_NORMALIZADA')

# %%
data_order_items
# Out:
#                                 order_id                        product_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1       00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2       000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3       00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4       00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
# ...                                  ...                               ...
# 112645  fffc94f6ce00a00581880bf54a75a037  4aa6014eceb682077f9dc4bffebc05b0
# 112646  fffcd46ef2263f404302a634eb57f7eb  32e07fd915822b0765e448c4dd74c828
# 112647  fffce4705a9662cd70adb13d4a31832d  72a30483855e2eafc67aee5dc2560482
# 112648  fffe18544ffabc95dfada21779c9644f  9c422a519119dcad7575db5af1ba540e
# 112649  fffe41c64501cc87c801fd61db3f6244  350688d9dc1e75ff97be326363655e01
#
# ...
