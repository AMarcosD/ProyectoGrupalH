# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_parquet(r'C:\Users\marco\Desktop\ProyectoGrupalH\dataparquet\data_customerP')

# %%
dfgeo = pd.read_parquet(r'C:\Users\marco\Desktop\ProyectoGrupalH\dataparquet\geolocation_cleanP')

# %%
dfgeo
# Out:
#        zip_code  geolatitud  geolongitud          city state      state_name  \
# 0          1037  -23.545621   -46.639292     Sao Paulo    SP       São Paulo
# 1          1046  -23.546081   -46.644820     Sao Paulo    SP       São Paulo
# 2          1041  -23.544392   -46.639499     Sao Paulo    SP       São Paulo
# 3          1035  -23.541578   -46.641607     Sao Paulo    SP       São Paulo
# 4          1012  -23.547762   -46.635361     Sao Paulo    SP       São Paulo
# ...         ...         ...          ...           ...   ...             ...
# 19010     89985  -26.348809   -53.276977    Palma Sola    SC  Santa Catarina
# 19011     89915  -26.918985   -53.614916  Santa Helena    SC  Santa Catarina
# 19012     89909  -26.654913   -53.438878  Barra Bonita    SC  Santa Catarina
# 19013     89925  -26.843127   -53.580079      Belmonte    SC  Santa Catarina
# 19014     89905  -26.764144   -53.640884   Bandeirante    SC  Santa Catarina
#
# ...

# %%
df = df[['customer_id', 'customer_unique_id', 'zip_code']].merge(dfgeo[['zip_code','geolatitud', 'geolongitud', 'city', 'state', 'state_name']], on='zip_code')
df
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      5dca924cc99eea2dc5ba40d11ec5dd0f  2761fee7f378f0a8d7682d8a3fa07ab1
# 2      661897d4968f1b59bfff74c7eb2eb4fc  d06a495406b79cb8203ea21cc0942f8c
# 3      702b62324327ccba20f1be3465426437  8b3d988f330c1d1c3332ccd440c147b7
# 4      bdf997bae7ca819b0415f5174d6b4302  866755e25db620f8d7e81b351a15bb2f
# ...                                 ...                               ...
# 99158  0b7a30ba373aeb55cf28add5b5477956  8c8173e547e020f411aa55b2fceed861
# 99159  ff6b440b2465bfaef05c675efb48cd15  e38a27b979a552e019e297ecc22dc67b
# 99160  3f7029d9b98a47370cd5f3a97adcbccd  5894d202cc869b4ec460fce3c6ed8cb5
# 99161  d9110683c7a282144e9fc97660026a28  5cbfdb85ec130898108b32c50d619c39
# 99162  6fb4f2354f36e554ac80141e9128f528  3cc6f2e1b9199837fabb35ff4bf24884
#
#        zip_code  geolatitud  geolongitud                  city state  \
# ...
